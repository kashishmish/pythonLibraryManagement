# %%
from IPython.display import clear_output,Image,display
from getpass import getpass
from datetime import date
import random
import datetime
while True:
    display(Image("library management.png"))
    print("Enter in which section you want to go")
    print("1. for admin")
    print("2. for users")
    print("3. for exit")
    n=int(input())
    if(n==1):
        clear_output()
        print("***************")
        print("*WELCOME ADMIN*")
        print("***************\n\n")
        print("ENTER USERNAME")
        u=input()
        print("ENTER PASSWORD")
        q=getpass("")
        s="kashmish"
        s1="kashish"
    while(n==1):
        if u==s and q==s1:
            clear_output()
            print("HELLO ADMIN\n\n")
            print("1. To add the book")
            print("2. To delete the book")
            print("3. To check which books are with user")
            print("4. To search for any book")
            print("5. To see all the books")
            print("6. To see all the existing users")
            print("7. To search the book by the author")
            print("8. To return to the main menu")
            print(" ")
            p=int(input())
            
            if p==1:
                clear_output()
                print("Enter how many books you want to add")
                c=int(input())
                for i in range(1,c+1):
                    print("Enter the book name")
                    book=input()
                    print("Enter the book author")
                    k=input()
                    f=open("totalbooks.txt","a")
                    f.write(book+"\n")
                    f.truncate()
                    f.close
                    g=open("books_author.txt","a")
                    g.write(book+" "+k+"\n")
                    g.truncate()
                    g.close
                    clear_output()
                print("added successfully")
                print("Press 1 to continue in admin section and 2 for the main menu")
                br=input()
                if br=="2":
                    break
            elif p==2:
                clear_output()
                f=open("totalbooks.txt","r")
                print(f.read())
                f.close
                print("Enter the book you wanted to delete")
                delbook=input()
                with open("totalbooks.txt","r") as file:
                    line=file.readlines()
                with open("totalbooks.txt","w") as file:
                    for i in line:
                        if i.strip("\n")!=delbook:
                            file.write(i)
                with open("books_author.txt","r") as file:
                    line=file.readlines()
                with open("books_author.txt","w") as file:
                    for i in line:
                        if i[:i.find(" ")]!=delbook:
                            file.write(i)

                print("deleted successfully")
                print("Press 1 to continue in admin section and 2 for the main menu")
                kl=input()
                if kl=="2":
                    break
            elif p==3:
                clear_output()
                g=open("username_issuedbook.txt","r")
                for i in g.readlines():
                    print("BOOK WHICH IS ISSUED IS")
                    print(i[0:i.find(" ")])
                    print("ISSUED BY")
                    print(i[i.find(" "):-1])
                g.close
                print("Press 1 to continue in admin section and 2 for the main menu")
                kl=input()
                if kl=="2":
                    break

            elif p==4:
                d=1
                c=0
                clear_output()
                print("Enter which book you want to search")
                book=input()
                f=open("totalbooks.txt","r")
                for line in f.readlines():
                    if line==book+"\n":
                        c=c+1
                        break
                    else:
                        d=d+1
                if c!=0:
                    print(f"Yes found at {d}")
                else:
                    print("Not found")
                f.close
                print("Press 1 to continue in admin section and 2 for the main menu")
                kl=input()
                if kl=="2":
                    break
            elif p==5:
                clear_output()
                f=open("totalbooks.txt","r")
                print(f.read())
                f.close
                print("Press 1 to continue in admin section and 2 for the main menu")
                kl=input()
                if kl=="2":
                    break
            elif p==6:
                clear_output()
                kash=open("allusers.txt","r")
                print(kash.read())
                kash.close
                print("Press 1 to continue in admin section and 2 for the main menu")
                kl=input()
                if kl=="2":
                    break
            
            elif p==7:
                print("Enter the name of the author whose book you are searching for")
                name=input()
                o=1
                c=0
                f=open("books_author.txt","r")
                for line in f.readlines():
                    if line[line.find(" ")+1:]==name+"\n":
                        c=c+1
                        book=line[0:line.find(" ")]
                        break
                    else:
                        o=o+1
                if c!=0:
                    print(f"Yes found at {o}")
                    print(f"The Book is {book}")
                else:
                    print("Not found")
                f.close
                print("Press 1 to continue in admin section and 2 for the main menu")
                kl=input()
                if kl=="2":
                    break

            elif p==8:
                clear_output()
                print("THANKS FOR COMING")
                break
        elif u!=s or q!=s1:
            clear_output()
            print("INVALID USERNAME OR PASSWORD")
            print("Press 1 to continue...")
            rr=input()
            if rr!=1:
                break
    while n==2:
        print("****************")
        print("* WELCOME USER *")
        print("****************\n\n")
        print("Enter 1 to log in")
        print("Enter 2 to register")
        w=int(input())         
        if w==1:
            j=0
            print("Your user name:")
            user=input()
            print("your password:")
            pas=getpass("")
            x=user+pas
            fi=open("allusers.txt","r")
            re=fi.readlines()
            for i in re:
                if i.strip("\n")==x:
                    j=j+1
                    break
            fi.close
            if j>0:
                clear_output()
                print("\n\nWelcome User\n\n")
                print("Enter what you want to do")
                print("1. To search any book")
                print("2. To issue any book")
                print("3. To return any book")
                print("4. To see all the books")
                print("5. To delete the account")
                print("6. To search the book with author name")
                print("7. To return to main menu\n")
                en=int(input())
                if en==1:
                    clear_output()
                    de=1
                    ce=0
                    
                    print("Enter which book you want to search")
                    book=input()
                    f=open("totalbooks.txt","r")
                    for line in f.readlines():
                        if line==book+"\n":
                            ce=ce+1
                            break
                        else:
                            de=de+1
                    if ce!=0:
                        print(f"Yes found at {de}")
                    else:
                        print("Not found")
                    f.close
                    print("Press 1 to continue in user section and 2 for the main menu")
                    kl=input()
                    if kl=="2":
                        break
                elif en==2:
                    clear_output()
                    ce=0
                    de=1
                    f=open("totalbooks.txt","r")
                    print(f.read())
                    f.close
                    print("Enter the name of the book you want to issue")
                    inputbook=input()
                    f=open("totalbooks.txt","r")
                    for line in f.readlines():
                        if line==inputbook+"\n":
                            ce=ce+1
                            break
                        else:
                            de=de+1
                    if ce!=0:
                        print(f"Yes found at {de}")
                        op=open("username_issuedbook.txt","a")
                        op.write(inputbook+" "+x+"\n")
                        op.truncate()
                        op.close
                        with open("totalbooks.txt","r") as file:
                            line=file.readlines()
                        with open("totalbooks.txt","w") as file:
                            for i in line:
                                if i.strip("\n")!=inputbook:
                                    file.write(i)
                        print("issued successfully!!")
                        
                        today=date.today()
                        ct=today.strftime("%d/%m/%y")
                        print(f"issued date ={ct}")
                        fg=open("book_issue_date.txt","a")
                        fg.write(inputbook+" "+ct+"\n")
                        fg.truncate()
                        fg.close
                    else:
                        print("YOU CAN NOT ISSUE THIS BOOK AS THIS IS NOT PRESENT IN THE LIBRARY")
                    print("Press 1 to continue in user section and 2 for the main menu")
                    kl=input()
                    if kl=="2":
                        break

                elif en==3:
                    clear_output()
                    print("Thanks for using the book")
                    flow=open("totalbooks.txt","a")
                    with open("username_issuedbook.txt","r") as fg:
                        li=fg.readlines()
                    with open("username_issuedbook.txt","w") as fg:
                        for l in li:
                            v=l[l.find(" ")+1:-1]
                            z=l[0:l.find(" ")]
                            if v.strip("\n")!=x:
                                fg.write(l)
                            else:
                                flow.write(z+"\n")
                                flow.truncate()
                                flow.close
                    print("returned successfully")
                    
                    
                    today=date.today()
                    ct=today.strftime("%d/%m/%y")
                    print(f"returned date ={ct}")
                    fg=open("book_issue_date.txt","r")
                    lin=fg.readlines()
                    fine=0
                    fg.close
                    with open("book_issue_date.txt","r") as file:
                        line=file.readlines()
                    with open("book_issue_date.txt","w") as file:
                        for i in line:
                            if i.strip("\n")!=z+" "+ct:
                                file.write(i)
                    for i in lin:
                        if i[:i.find(" ")]==z:
                            inputis=i
                            strg1=i[i.find(" ")+1:]
                            strg2=ct
                            a1,a2,a3=strg1.split("/")
                            b1,b2,b3=strg2.split("/")
                            a1=int(a1)
                            a2=int(a2)
                            a3=int(a3)
                            b1=int(b1)
                            b2=int(b2)
                            b3=int(b3)
                            d1=datetime.datetime(a3,a2,a1)
                            d2=datetime.datetime(b3,b2,b1)
                            diff=d2-d1
                            diff=str(diff)
                            if diff[0]>"7":
                                number=int(diff[0])
                                num1=(number-7)*5
                                print(f"now you will have to pay the fine of {num1} because you have taken {number} more days to return the book. ")
                                fine=1
                    if fine==0:
                        print("No fine")
                    
                    print("Press 1 to continue in user section and 2 for the main menu")
                    kl=input()
                    if kl=="2":
                        break
                elif en==4:
                    clear_output()
                    print("ALL THE BOOKS ARE:")
                    f=open("totalbooks.txt","r")
                    print(f.read())
                    f.close
                    print("Press 1 to continue in user section and 2 for the main menu")
                    kl=input()
                    if kl=="2":
                        break
                elif en==5:
                    clear_output()
                    print("Enter the user name and password")
                    user=input()
                    password=getpass("")
                    list123=[]
                    g=open("username_issuedbook.txt","r")
                    for i in g.readlines():
                        list123.append(i[i.find(" "):-1])
                    g.close
                    if " "+user+password in list123:
                        print("Sorry you have issued the book so you cannot delete your account")
                    else:
                        with open("allusers.txt","r") as file:
                            line=file.readlines()
                        with open("allusers.txt","w") as file:
                            for i in line:
                                if i.strip("\n")!=user+password:
                                    file.write(i)
                        print("deleted successfully")
                    print("Press 1 to continue in user section and 2 for the main menu")
                    kl=input()
                    if kl=="2":
                        break
                    
                elif en==6:
                    print("Enter the name of the author whose book you are searching for")
                    name=input()
                    o=1
                    c=0
                    f=open("books_author.txt","r")
                    for line in f.readlines():
                        if line[line.find(" ")+1:]==name+"\n":
                            c=c+1
                            book=line[0:line.find(" ")]
                            break
                        else:
                            o=o+1
                    if c!=0:
                        print(f"Yes found at {o}")
                        print(f"The Book is {book}")
                    else:
                        print("Not found")
                    f.close
                    print("Press 1 to continue in user section and 2 for the main menu")
                    kl=input()
                    if kl=="2":
                        break    

                elif en==7:
                    clear_output()
                    print("THANKS FOR COMING")
                    break
            else:
                clear_output()
                print("\n\nSorry you are not registered please register yourself")
                break
            fi.close
        elif w==2:
            clear_output()
            print("Enter the user id ")
            us=input()
            
            print("Enter the password")
            pa=getpass("")
            y=us+pa
            lo=0
            fi=open("allusers.txt","r")
            re=fi.readlines()
            for i in re:
                if i.strip("\n")==y:
                    lo=lo+1
                    break
            fi.close
            if lo>0:
                print("Sorry this account is already in existence so you can login with this account")
                break
            else:

                fi=open("allusers.txt","a")
                fi.write(y+"\n")
                fi.truncate()
                fi.close
                print("Thanks for registering!!")
                print("Press 1 to continue...")
                pol=input()
                if pol!="1":
                    break
            
    if n==3:
        clear_output()
        display(Image("rename.png"))
        print("Thanks for using the library.")
        break
# Out:
# Thanks for using the book
# returned successfully
# returned date =11/05/21
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-3bf85160c9cb> in <module>
#     314                             a1,a2,a3=strg1.split("/")
#     315                             b1,b2,b3=strg2.split("/")
# --> 316                             a1=int(a1)
#     317                             a2=int(a2)
#     318                             a3=int(a3)
#
# ValueError: invalid literal for int() with base 10: 'Potter 11'

# %% [markdown]
# #

# %% [raw]
# ## with ope7n("bo","r") as f:
#     lines=f.readlines()
# with open("bo","w") as f:
#     for line in lines:
#         if li2
#         ne.strip("\n")!="rockstar":
#             f.write(line)

# %%
list123=[]
g=open("c.txt","r")
for i in g.readlines():
    print("BOOK WHICH IS ISSUED IS")
    print(i[0:i.find(" ")])
    print("ISSUED BY")
    print(i[i.find(" "):-1])
    list123.append(i[i.find(" "):-1])
g.close
print(list123[0])
# Out:
# BOOK WHICH IS ISSUED IS
# coa
# ISSUED BY
#  sheelamishra
# BOOK WHICH IS ISSUED IS
# algorithms
# ISSUED BY
#  shubhammishra
#  sheelamishra

# %%
from datetime import datetime
now=datetime.now()
current_time=now.strftime("%H:%M:%S")
print(f"current time={current_time}")
type(current_time)
# Out:
# current time=19:04:52
# str

# %%
import datetime
a=datetime.datetime(2017,6,21,0,0,0)
b=datetime.datetime(2017,5,16,0,0,0)
print(a-b)
# Out:
# 36 days, 0:00:00

# %%
import random
r=random.randint(1,10)
print(r)
# Out:
# 5
